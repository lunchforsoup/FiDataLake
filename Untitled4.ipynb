# %%
import dagit

# %%
dagit
# Out:
# <module 'dagit' from 'C:\\Users\\johnf\\anaconda4\\lib\\site-packages\\dagit\\__init__.py'>

# %%
import os

os.path.abspath()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 import os
# ----> 3 os.path.abspath()
#
# TypeError: abspath() missing 1 required positional argument: 'path'

# %%
import pathlib
pathlib.Path().resolve()
# Out:
# WindowsPath('C:/Users/johnf')

# %%
CONDA LIST
# Out:
#   Input In [4]
#     CONDA LIST
#           ^
# SyntaxError: invalid syntax

# %%
conda list
# Out:
# # packages in environment at C:\Users\johnf\anaconda4:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2021.11                  py39_0
# _ipyw_jlab_nb_ext_conf    0.1.0            py39haa95532_0
# absl-py                   1.0.0                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# alembic                   1.6.5              pyhd8ed1ab_0    conda-forge
# anaconda                  custom                   py39_1
# anaconda-client           1.9.0            py39haa95532_0
# anaconda-navigator        2.1.4            py39haa95532_0
# anaconda-project          0.10.2             pyhd3eb1b0_0
# aniso8601                 7.0.0                    pypi_0    pypi
# anyio                     3.5.0            py39haa95532_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argh                      0.26.2           py39haa95532_0
# ...
